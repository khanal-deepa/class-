# %%
import os
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.utils import to_categorical

# Loading the model.
MODEL_NAME = 'users/asl_alphabet.h5'
model = load_model(MODEL_NAME)

# Setting up the input image size and frame crop size.
IMAGE_SIZE = 200
CROP_SIZE = 400

# Creating list of available classes stored in classes.txt.
classes_file = open("users/classes.txt")
classes_string = classes_file.readline()
classes = classes_string.split()
classes.sort()  # The predict function sends out output in sorted order.

# Path to the testing dataset
testing_dataset_path = "data/asl_alphabet_test"

# Iterate through the testing dataset
for class_name in classes:
    class_path = os.path.join(testing_dataset_path, class_name)
    for image_filename in os.listdir(class_path):
        # Load and preprocess the image
        image_path = os.path.join(class_path, image_filename)
        img = load_img(image_path, target_size=(IMAGE_SIZE, IMAGE_SIZE))
        img_array = img_to_array(img)
        img_array = img_array.reshape((1, IMAGE_SIZE, IMAGE_SIZE, 3))
        img_array = img_array.astype('float32') / 255.0

        # Predicting the frame.
        prediction = model.predict(img_array)
        predicted_class = classes[prediction.argmax()]  # Selecting the max confidence index.

        # Preparing output based on the model's confidence.
        prediction_text = 'Prediction: {}'.format(predicted_class)
        confidence = 'Confidence: {:.2f}%'.format(prediction[0, prediction.argmax()] * 100)
        print(prediction_text, confidence)

        # Display the image with prediction.
        img = cv2.imread(image_path)
        cv2.putText(img, prediction_text, (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        cv2.imshow('Validation Image', img)
        cv2.waitKey(0)

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 28
#      26 for class_name in classes:
#      27     class_path = os.path.join(testing_dataset_path, class_name)
# ---> 28     for image_filename in os.listdir(class_path):
#      29         # Load and preprocess the image
#      30         image_path = os.path.join(class_path, image_filename)
#      31         img = load_img(image_path, target_size=(IMAGE_SIZE, IMAGE_SIZE))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/asl_alphabet_test/A'

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# Loading the model.
MODEL_NAME = 'users/asl_alphabet_{}.h5'.format(9575)
model = load_model(MODEL_NAME)

# Setting up the input image size.
IMAGE_SIZE = 200

# Creating list of available classes stored in classes.txt.
classes_file = open("users/classes.txt")
classes_string = classes_file.readline()
classes = classes_string.split()
classes.sort()  # The predict function sends out output in sorted order.

# Path to the testing dataset
testing_dataset_path = "data/asl_alphabet_test"

# Iterate through the testing dataset
for image_filename in os.listdir(testing_dataset_path):
    # Load and preprocess the image
    image_path = os.path.join(testing_dataset_path, image_filename)
    img = load_img(image_path, target_size=(IMAGE_SIZE, IMAGE_SIZE))
    img_array = img_to_array(img)
    img_array = img_array.reshape((1, IMAGE_SIZE, IMAGE_SIZE, 3))
    img_array = img_array.astype('float32') / 255.0

    # Predicting the frame.
    prediction = model.predict(img_array)
    predicted_class = classes[prediction.argmax()]  # Selecting the max confidence index.

    # Preparing output based on the model's confidence.
    prediction_text = 'Prediction: {}'.format(predicted_class)
    confidence = 'Confidence: {:.2f}%'.format(prediction[0, prediction.argmax()] * 100)
    print(prediction_text, confidence)

    # Display the image with prediction.
    img = cv2.imread(image_path)
    cv2.putText(img, prediction_text, (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
    cv2.imshow('Validation Image', img)
    cv2.waitKey(0)

cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 1s 855ms/step
# Prediction: nothing Confidence: 88.99%
# 1/1 [==============================] - 0s 39ms/step
# Prediction: G Confidence: 97.12%
# 1/1 [==============================] - 0s 38ms/step
# Prediction: H Confidence: 98.85%
# 1/1 [==============================] - 0s 38ms/step
# Prediction: J Confidence: 98.15%
# 1/1 [==============================] - 0s 41ms/step
# Prediction: E Confidence: 68.38%
# 1/1 [==============================] - 0s 38ms/step
# Prediction: O Confidence: 83.74%
# 1/1 [==============================] - 0s 37ms/step
# Prediction: I Confidence: 75.89%
# 1/1 [==============================] - 0s 36ms/step
# Prediction: F Confidence: 94.96%
# 1/1 [==============================] - 0s 43ms/step
# Prediction: C Confidence: 98.06%
# 1/1 [==============================] - 0s 36ms/step
# Prediction: R Confidence: 96.82%
# 1/1 [==============================] - 0s 36ms/step
# Prediction: Z Confidence: 94.50%
# ...

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from IPython.display import display, Image

# %%
# Loading the model.
MODEL_NAME = 'users/asl_alphabet_{}.h5'.format(9575)
model = load_model(MODEL_NAME)

# Setting up the input image size.
IMAGE_SIZE = 200

# Creating list of available classes stored in classes.txt.
classes_file = open("users/classes.txt")
classes_string = classes_file.readline()
classes = classes_string.split()
classes.sort()  # The predict function sends out output in sorted order.

# Path to the testing dataset
testing_dataset_path = "data/asl_alphabet_test"

# Iterate through the testing dataset
for image_filename in os.listdir(testing_dataset_path):
    # Load and preprocess the image
    image_path = os.path.join(testing_dataset_path, image_filename)
    img = load_img(image_path, target_size=(IMAGE_SIZE, IMAGE_SIZE))
    img_array = img_to_array(img)
    img_array = img_array.reshape((1, IMAGE_SIZE, IMAGE_SIZE, 3))
    img_array = img_array.astype('float32') / 255.0

    # Predicting the frame.
    prediction = model.predict(img_array)
    predicted_class = classes[prediction.argmax()]  # Selecting the max confidence index.

    # Preparing output based on the model's confidence.
    prediction_text = 'Prediction: {}'.format(predicted_class)
    confidence = 'Confidence: {:.2f}%'.format(prediction[0, prediction.argmax()] * 100)
    print(prediction_text, confidence)

    # Display the image with prediction in Jupyter Notebook.
    display(Image(filename=image_path))

# Optionally, you can add a delay to control the display speed.
# import time
# time.sleep(2)
# Out:
# 1/1 [==============================] - 1s 839ms/step
# Prediction: nothing Confidence: 88.99%
# 1/1 [==============================] - 0s 40ms/step
# Prediction: G Confidence: 97.12%
# 1/1 [==============================] - 0s 41ms/step
# Prediction: H Confidence: 98.85%
# 1/1 [==============================] - 0s 38ms/step
# Prediction: J Confidence: 98.15%
# 1/1 [==============================] - 0s 37ms/step
# Prediction: E Confidence: 68.38%
# 1/1 [==============================] - 0s 38ms/step
# Prediction: O Confidence: 83.74%
# 1/1 [==============================] - 0s 39ms/step
# Prediction: I Confidence: 75.89%
# 1/1 [==============================] - 0s 40ms/step
# Prediction: F Confidence: 94.96%
# 1/1 [==============================] - 0s 38ms/step
# Prediction: C Confidence: 98.06%
# 1/1 [==============================] - 0s 38ms/step
# Prediction: R Confidence: 96.82%
# 1/1 [==============================] - 0s 40ms/step
# Prediction: Z Confidence: 94.50%
# ...

# %%
# Loading the model.
MODEL_NAME = 'users/asl_alphabet_{}.h5'.format(9575)
model = load_model(MODEL_NAME)

# Setting up the input image size.
IMAGE_SIZE = 200

# Creating list of available classes stored in classes.txt.
classes_file = open("users/classes.txt")
classes_string = classes_file.readline()
classes = classes_string.split()
classes.sort()  # The predict function sends out output in sorted order.

# Path to the testing dataset
testing_dataset_path = "data/asl_alphabet_test"

# Iterate through the testing dataset
for image_filename in os.listdir(testing_dataset_path):
    # Extract the actual class from the filename
    actual_class = image_filename.split('_')[0]

    # Load and preprocess the image
    image_path = os.path.join(testing_dataset_path, image_filename)
    img = load_img(image_path, target_size=(IMAGE_SIZE, IMAGE_SIZE))
    img_array = img_to_array(img)
    img_array = img_array.reshape((1, IMAGE_SIZE, IMAGE_SIZE, 3))
    img_array = img_array.astype('float32') / 255.0

    # Predicting the frame.
    prediction = model.predict(img_array)
    predicted_class = classes[prediction.argmax()]  # Selecting the max confidence index.

    # Preparing output based on the model's confidence.
    prediction_text = f'Actual: {actual_class}, Prediction: {predicted_class}'
    confidence = 'Confidence: {:.2f}%'.format(prediction[0, prediction.argmax()] * 100)
    print(prediction_text, confidence)

    # Display the image with prediction in Jupyter Notebook.
    display(Image(filename=image_path))

# Optionally, you can add a delay to control the display speed.
# import time
# time.sleep(2)
# Out:
# 1/1 [==============================] - 1s 886ms/step
# Actual: nothing, Prediction: nothing Confidence: 88.99%
# 1/1 [==============================] - 0s 46ms/step
# Actual: G, Prediction: G Confidence: 97.12%
# 1/1 [==============================] - 0s 45ms/step
# Actual: H, Prediction: H Confidence: 98.85%
# 1/1 [==============================] - 0s 45ms/step
# Actual: J, Prediction: J Confidence: 98.15%
# 1/1 [==============================] - 0s 45ms/step
# Actual: E, Prediction: E Confidence: 68.38%
# 1/1 [==============================] - 0s 42ms/step
# Actual: O, Prediction: O Confidence: 83.74%
# 1/1 [==============================] - 0s 38ms/step
# Actual: I, Prediction: I Confidence: 75.89%
# 1/1 [==============================] - 0s 37ms/step
# Actual: F, Prediction: F Confidence: 94.96%
# 1/1 [==============================] - 0s 38ms/step
# Actual: C, Prediction: C Confidence: 98.06%
# 1/1 [==============================] - 0s 42ms/step
# ...

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# Loading the model.
MODEL_NAME = 'users/asl_alphabet.h5'
model = load_model(MODEL_NAME)

# Setting up the input image size.
IMAGE_SIZE = 200

# Creating list of available classes stored in classes.txt.
classes_file = open("users/classes.txt")
classes_string = classes_file.readline()
classes = classes_string.split()
classes.sort()  # The predict function sends out output in sorted order.

# Path to the testing dataset
testing_dataset_path = "data/asl_alphabet_test"

# Iterate through the testing dataset
for image_filename in os.listdir(testing_dataset_path):
    # Load and preprocess the image
    image_path = os.path.join(testing_dataset_path, image_filename)
    img = load_img(image_path, target_size=(IMAGE_SIZE, IMAGE_SIZE))
    img_array = img_to_array(img)
    img_array = img_array.reshape((1, IMAGE_SIZE, IMAGE_SIZE, 3))
    img_array = img_array.astype('float32') / 255.0

    # Predicting the frame.
    prediction = model.predict(img_array)
    predicted_class = classes[prediction.argmax()]  # Selecting the max confidence index.

    # Preparing output based on the model's confidence.
    prediction_text = 'Prediction: {}'.format(predicted_class)
    confidence = 'Confidence: {:.2f}%'.format(prediction[0, prediction.argmax()] * 100)
    print(prediction_text, confidence)

    # Display the image with prediction.
    img = cv2.imread(image_path)
    cv2.putText(img, prediction_text, (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
    cv2.imshow('Validation Image', img)
    cv2.waitKey(0)

cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 2s 2s/step
# Prediction: nothing Confidence: 88.99%
# 1/1 [==============================] - 0s 68ms/step
# Prediction: G Confidence: 97.12%
# 1/1 [==============================] - 0s 70ms/step
# Prediction: H Confidence: 98.85%
# 1/1 [==============================] - 0s 66ms/step
# Prediction: J Confidence: 98.15%
# 1/1 [==============================] - 0s 69ms/step
# Prediction: E Confidence: 68.38%
# 1/1 [==============================] - 0s 68ms/step
# Prediction: O Confidence: 83.74%
# 1/1 [==============================] - 0s 60ms/step
# Prediction: I Confidence: 75.89%
# 1/1 [==============================] - 0s 68ms/step
# Prediction: F Confidence: 94.96%
# 1/1 [==============================] - 0s 66ms/step
# Prediction: C Confidence: 98.06%
# 1/1 [==============================] - 0s 63ms/step
# Prediction: R Confidence: 96.82%
# 1/1 [==============================] - 0s 68ms/step
# Prediction: Z Confidence: 94.50%
# ...

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# Loading the model.
MODEL_NAME = 'users/asl_alphabet.h5'
model = load_model(MODEL_NAME)

# Setting up the input image size.
IMAGE_SIZE = 200

# Creating list of available classes stored in classes.txt.
classes_file = open("users/classes.txt")
classes_string = classes_file.readline()
classes = classes_string.split()
classes.sort()  # The predict function sends out output in sorted order.

# Path to the testing dataset
testing_dataset_path = "data/asl_alphabet_test"

total_confidence = 0
total_predictions = 0

# Iterate through the testing dataset
for image_filename in os.listdir(testing_dataset_path):
    # Load and preprocess the image
    image_path = os.path.join(testing_dataset_path, image_filename)
    img = load_img(image_path, target_size=(IMAGE_SIZE, IMAGE_SIZE))
    img_array = img_to_array(img)
    img_array = img_array.reshape((1, IMAGE_SIZE, IMAGE_SIZE, 3))
    img_array = img_array.astype('float32') / 255.0

    # Predicting the frame.
    prediction = model.predict(img_array)
    predicted_class = classes[prediction.argmax()]  # Selecting the max confidence index.

    # Preparing output based on the model's confidence.
    prediction_text = 'Prediction: {}'.format(predicted_class)
    confidence = prediction[0, prediction.argmax()]
    total_confidence += confidence
    total_predictions += 1
    print(prediction_text, 'Confidence: {:.2f}%'.format(confidence * 100))

    # Display the image with prediction.
    img = cv2.imread(image_path)
    cv2.putText(img, prediction_text, (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
    cv2.imshow('Validation Image', img)
    cv2.waitKey(0)

# Calculate overall confidence
overall_confidence = total_confidence / total_predictions
print('Overall Confidence: {:.2f}%'.format(overall_confidence * 100))

cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 1s 1s/step
# Prediction: nothing Confidence: 88.99%
# 1/1 [==============================] - 0s 43ms/step
# Prediction: G Confidence: 97.12%
# 1/1 [==============================] - 0s 42ms/step
# Prediction: H Confidence: 98.85%
# 1/1 [==============================] - 0s 42ms/step
# Prediction: J Confidence: 98.15%
# 1/1 [==============================] - 0s 41ms/step
# Prediction: E Confidence: 68.38%
# 1/1 [==============================] - 0s 46ms/step
# Prediction: O Confidence: 83.74%
# 1/1 [==============================] - 0s 51ms/step
# Prediction: I Confidence: 75.89%
# 1/1 [==============================] - 0s 45ms/step
# Prediction: F Confidence: 94.96%
# 1/1 [==============================] - 0s 45ms/step
# Prediction: C Confidence: 98.06%
# 1/1 [==============================] - 0s 48ms/step
# Prediction: R Confidence: 96.82%
# 1/1 [==============================] - 0s 42ms/step
# Prediction: Z Confidence: 94.50%
# ...

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# Loading the model.
MODEL_NAME = 'users/asl_alphabet.h5'
model = load_model(MODEL_NAME)

# Setting up the input image size.
IMAGE_SIZE = 200

# Creating list of available classes stored in classes.txt.
classes_file = open("users/classes.txt")
classes_string = classes_file.readline()
classes = classes_string.split()
classes.sort()  # The predict function sends out output in sorted order.

# Path to the testing dataset
testing_dataset_path = "data/test"

total_confidence = 0
total_predictions = 0

# Iterate through the testing dataset
for image_filename in os.listdir(testing_dataset_path):
    # Load and preprocess the image
    image_path = os.path.join(testing_dataset_path, image_filename)
    img = load_img(image_path, target_size=(IMAGE_SIZE, IMAGE_SIZE))
    img_array = img_to_array(img)
    img_array = img_array.reshape((1, IMAGE_SIZE, IMAGE_SIZE, 3))
    img_array = img_array.astype('float32') / 255.0

    # Predicting the frame.
    prediction = model.predict(img_array)
    predicted_class = classes[prediction.argmax()]  # Selecting the max confidence index.

    # Preparing output based on the model's confidence.
    prediction_text = 'Prediction: {}'.format(predicted_class)
    confidence = prediction[0, prediction.argmax()]
    total_confidence += confidence
    total_predictions += 1
    print(prediction_text, 'Confidence: {:.2f}%'.format(confidence * 100))

    # Display the image with prediction.
    img = cv2.imread(image_path)
    cv2.putText(img, prediction_text, (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
    cv2.imshow('Validation Image', img)
    cv2.waitKey(0)

# Calculate overall confidence
overall_confidence = total_confidence / total_predictions
print('Overall Confidence: {:.2f}%'.format(overall_confidence * 100))

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[3], line 30
#      27 for image_filename in os.listdir(testing_dataset_path):
#      28     # Load and preprocess the image
#      29     image_path = os.path.join(testing_dataset_path, image_filename)
# ---> 30     img = load_img(image_path, target_size=(IMAGE_SIZE, IMAGE_SIZE))
#      31     img_array = img_to_array(img)
#      32     img_array = img_array.reshape((1, IMAGE_SIZE, IMAGE_SIZE, 3))
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/src/utils/image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# ...

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# Loading the model.
MODEL_NAME = 'users/asl_alphabet.h5'
model = load_model(MODEL_NAME)

# Setting up the input image size.
IMAGE_SIZE = 200

# Creating list of available classes stored in classes.txt.
classes_file = open("users/classes.txt")
classes_string = classes_file.readline()
classes = classes_string.split()
classes.sort()  # The predict function sends out output in sorted order.

# Path to the testing dataset
testing_dataset_path = "data/test"

total_confidence = 0
total_predictions = 0

# Iterate through the testing dataset
for folder_name in os.listdir(testing_dataset_path):
    folder_path = os.path.join(testing_dataset_path, folder_name)
    if not os.path.isdir(folder_path):
        continue  # Skip if not a directory
    # Iterate through images in the folder
    for image_filename in os.listdir(folder_path):
        image_path = os.path.join(folder_path, image_filename)
        # Load and preprocess the image
        img = load_img(image_path, target_size=(IMAGE_SIZE, IMAGE_SIZE))
        img_array = img_to_array(img)
        img_array = img_array.reshape((1, IMAGE_SIZE, IMAGE_SIZE, 3))
        img_array = img_array.astype('float32') / 255.0

        # Predicting the frame.
        prediction = model.predict(img_array)
        predicted_class = classes[prediction.argmax()]  # Selecting the max confidence index.

        # Preparing output based on the model's confidence.
        prediction_text = 'Prediction: {}'.format(predicted_class)
        confidence = prediction[0, prediction.argmax()]
        total_confidence += confidence
        total_predictions += 1
        print(prediction_text, 'Confidence: {:.2f}%'.format(confidence * 100))

        # Display the image with prediction.
        img = cv2.imread(image_path)
        cv2.putText(img, prediction_text, (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        cv2.imshow('Validation Image', img)
        cv2.waitKey(0)

# Calculate overall confidence
if total_predictions > 0:
    overall_confidence = total_confidence / total_predictions
    print('Overall Confidence: {:.2f}%'.format(overall_confidence * 100))
else:
    print('No images found in the testing dataset.')

cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 1s 1s/step
# Prediction: F Confidence: 58.04%
# 1/1 [==============================] - 0s 44ms/step
# Prediction: F Confidence: 23.16%
# 1/1 [==============================] - 0s 43ms/step
# Prediction: Y Confidence: 28.23%
# 1/1 [==============================] - 0s 43ms/step
# Prediction: F Confidence: 37.20%
# 1/1 [==============================] - 0s 44ms/step
# Prediction: nothing Confidence: 18.82%
# 1/1 [==============================] - 0s 42ms/step
# Prediction: R Confidence: 84.79%
# 1/1 [==============================] - 0s 46ms/step
# Prediction: nothing Confidence: 25.31%
# 1/1 [==============================] - 0s 45ms/step
# Prediction: R Confidence: 65.38%
# 1/1 [==============================] - 0s 46ms/step
# Prediction: D Confidence: 97.35%
# 1/1 [==============================] - 0s 50ms/step
# Prediction: D Confidence: 49.68%
# 1/1 [==============================] - 0s 43ms/step
# Prediction: D Confidence: 60.70%
# ...

# %%
import os
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# Loading the model.
MODEL_NAME = 'users/asl_alphabet.h5'
model = load_model(MODEL_NAME)

# Setting up the input image size.
IMAGE_SIZE = 200

# Creating list of available classes stored in classes.txt.
classes_file = open("users/classes.txt")
classes_string = classes_file.readline()
classes = classes_string.split()
classes.sort()  # The predict function sends out output in sorted order.

# Path to the testing dataset
testing_dataset_path = "data/test"

total_confidence = 0
total_predictions = 0

# Iterate through the testing dataset
for folder_name in os.listdir(testing_dataset_path):
    folder_path = os.path.join(testing_dataset_path, folder_name)
    if not os.path.isdir(folder_path):
        continue  # Skip if not a directory
    # Iterate through images in the folder
    for image_filename in os.listdir(folder_path):
        image_path = os.path.join(folder_path, image_filename)
        # Load and preprocess the image
        img = load_img(image_path, target_size=(IMAGE_SIZE, IMAGE_SIZE))
        img_array = img_to_array(img)
        img_array = img_array.reshape((1, IMAGE_SIZE, IMAGE_SIZE, 3))
        img_array = img_array.astype('float32') / 255.0

        # Predicting the frame.
        prediction = model.predict(img_array)
        predicted_class = classes[prediction.argmax()]  # Selecting the max confidence index.

        # Preparing output based on the model's confidence.
        confidence = prediction[0, prediction.argmax()]
        total_confidence += confidence
        total_predictions += 1
        print("Image:", image_path)
        print("Prediction: {}, Confidence: {:.2f}%".format(predicted_class, confidence * 100))

# Calculate overall confidence
if total_predictions > 0:
    overall_confidence = total_confidence / total_predictions
    print('Overall Confidence: {:.2f}%'.format(overall_confidence * 100))
else:
    print('No images found in the testing dataset.')
# Out:
# 1/1 [==============================] - 1s 1s/step
# Image: data/test/F/F2630.jpg
# Prediction: F, Confidence: 58.04%
# 1/1 [==============================] - 0s 69ms/step
# Image: data/test/F/F362.jpg
# Prediction: F, Confidence: 23.16%
# 1/1 [==============================] - 0s 47ms/step
# Image: data/test/F/F844.jpg
# Prediction: Y, Confidence: 28.23%
# 1/1 [==============================] - 0s 45ms/step
# Image: data/test/F/F208.jpg
# Prediction: F, Confidence: 37.20%
# 1/1 [==============================] - 0s 48ms/step
# Image: data/test/R/R1244.jpg
# Prediction: nothing, Confidence: 18.82%
# 1/1 [==============================] - 0s 45ms/step
# Image: data/test/R/R940.jpg
# Prediction: R, Confidence: 84.79%
# 1/1 [==============================] - 0s 44ms/step
# Image: data/test/R/R1098.jpg
# Prediction: nothing, Confidence: 25.31%
# 1/1 [==============================] - 0s 49ms/step
# Image: data/test/R/R252.jpg
# Prediction: R, Confidence: 65.38%
# ...

# %%
import os
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# Loading the model.
MODEL_NAME = 'users/asl_alphabet.h5'
model = load_model(MODEL_NAME)

# Setting up the input image size.
IMAGE_SIZE = 200

# Creating list of available classes stored in classes.txt.
classes_file = open("users/classes.txt")
classes_string = classes_file.readline()
classes = classes_string.split()
classes.sort()  # The predict function sends out output in sorted order.

# Path to the testing dataset
testing_dataset_path = "data/test"

total_correct_predictions = 0
total_predictions = 0

# Iterate through the testing dataset
for folder_name in os.listdir(testing_dataset_path):
    folder_path = os.path.join(testing_dataset_path, folder_name)
    if not os.path.isdir(folder_path):
        continue  # Skip if not a directory
    # Iterate through images in the folder
    for image_filename in os.listdir(folder_path):
        image_path = os.path.join(folder_path, image_filename)
        # Load and preprocess the image
        img = load_img(image_path, target_size=(IMAGE_SIZE, IMAGE_SIZE))
        img_array = img_to_array(img)
        img_array = img_array.reshape((1, IMAGE_SIZE, IMAGE_SIZE, 3))
        img_array = img_array.astype('float32') / 255.0

        # Predicting the frame.
        prediction = model.predict(img_array)
        predicted_class = classes[prediction.argmax()]  # Selecting the max confidence index.

        # Comparing predicted class with real label
        if predicted_class == folder_name:
            total_correct_predictions += 1
        total_predictions += 1

# Calculate accuracy
if total_predictions > 0:
    accuracy = total_correct_predictions / total_predictions
    print('Accuracy: {:.2f}%'.format(accuracy * 100))
else:
    print('No images found in the testing dataset.')
# Out:
# ...
# 1/1 [==============================] - 0s 50ms/step
# Accuracy: 58.47%

# %%
import os
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# Loading the model.
MODEL_NAME = 'users/asl_alphabet.h5'
model = load_model(MODEL_NAME)

# Setting up the input image size.
IMAGE_SIZE = 200

# Creating list of available classes stored in classes.txt.
classes_file = open("users/classes.txt")
classes_string = classes_file.readline()
classes = classes_string.split()
classes.sort()  # The predict function sends out output in sorted order.

# Path to the testing dataset
testing_dataset_path = "data/test"

total_correct_predictions = 0
total_predictions = 0

# Iterate through the testing dataset
for folder_name in os.listdir(testing_dataset_path):
    folder_path = os.path.join(testing_dataset_path, folder_name)
    if not os.path.isdir(folder_path):
        continue  # Skip if not a directory
    # Iterate through images in the folder
    for image_filename in os.listdir(folder_path):
        image_path = os.path.join(folder_path, image_filename)
        # Load and preprocess the image
        img = load_img(image_path, target_size=(IMAGE_SIZE, IMAGE_SIZE))
        img_array = img_to_array(img)
        img_array = img_array.reshape((1, IMAGE_SIZE, IMAGE_SIZE, 3))
        img_array = img_array.astype('float32') / 255.0

        # Predicting the frame.
        prediction = model.predict(img_array)
        predicted_class = classes[prediction.argmax()]  # Selecting the max confidence index.

        # Comparing predicted class with real label
        if predicted_class == folder_name:
            total_correct_predictions += 1
        total_predictions += 1

# Calculate accuracy
if total_predictions > 0:
    accuracy = total_correct_predictions / total_predictions
    print('Accuracy: {:.2f}%'.format(accuracy * 100))
else:
    print('No images found in the testing dataset.')
